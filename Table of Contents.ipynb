# %% [markdown]
# <center><h1>Table of Contents</h1></center>
# <h4>Part 1: Mathematics</h4>
# <ul>
# <li>Linear Algebra</li>
# <li>Probability</li>
# <li>Statistics</li>
# <li>Information Theory</li>
# <li>Calculus</li>
# </ul>
#
# <h4>Part 2: Machine Learning Basics</h4>
# <ul>
# <li>Types of Machine Learning</li>
# <li>Machine Learning Problems</li>
# <li>Overfitting/Underfitting</li>
# <li>Bias-Variance Trade-off</li>
# <li>Regularization</li>
# <li>The Curse of Dimensionality</li>
# <li>The No Free Lunch Theorem</li>
# <li>Parameters v.s. Hyperparameters</li>
# <li>Hyperparameter Tuning</li>
# <li>Train/Test Split</li>
# <li>Cross Validation</li>
# <li>Chaining</li>
# <li>Occam's Razor</li>
# <li>Feature Selection</li>
# <li>Generative vs Discriminative Models</li>
# <li>Performance Measurements</li>
#
# <li>Machine Learning Pipeline</li>
# </ul>
#
# <h4>Part 3: Popular Machine Learning Models</h4>
# <ul>
# <li>Linear Regression</li>
# <li>Logistic Regression</li>
# <li>Support Vector Machines</li>
# <li>Decision Trees</li>
# <li>Random Forest</li>
# <li>Naive Bayes Classifier</li>
# <li>K-Nearest Neighbors</li>
# <li>K-Means</li>
# <li>K-Medoids</li>
# <li>Affinity Propogation</li>
# <li>Principal Component Analysis (SVD)</li>
# <li>Singular Value Decomposition (PCA)</li>
# </ul>
#
# <h4>Part 4: Deep Learning Basics</h4>
# <ul>
# <li>Universal Function Approximation</li>
# <li>Feed Forward Networks</li>
# <li>Forward Propogation</li>
# <li>Backward Propogation</li>
# <li>Activation Functions</li>
# <li>Regularization</li>
# <li>Convolutional Neural Networks (CNNs)</li>
# <li>Recurrent Neural Networks (RNNs)</li>
#     <ul>
#     <li>GRUs</li>
#     <li>LSTMs</li>
#     </ul>
# <li>Autoencoders</li>
# <li>Sequence to Sequence Models</li>
# <li>Transfer Learning</li>
# </ul>
#
# <h4>Part 5: Popular Deep Learning Research Papers</h4>
# <ul>
# <li>Capsule Networks: Dynamic Routing Between Capsules</li>
# <li>Synthetic Gradients</li>
# <li>Generative Adversarial Networks</li>
# <li>Variational Autoencoders</li>
# <li>Neural Style Transfer</li>
# <li>VGG 16</li>
# <li>AlexNet</li>
# <li>YOLO</li>
# <li>Fast R-CNN</li>
# <li>Mask R-CNN</li>
# </ul>
